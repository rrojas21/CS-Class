# %%
#madlib code
color1 = input('Enter a color: ')
superlative = input('Enter a superlative (ending in "est"): ')
adj1 = input('Enter an adjective: ')
body_part_plural = input('Enter a body part (plural): ')
body_part = input('Enter a body part: ')
noun1 = input('Enter a noun: ')
animal1 = input('Enter an animal (plural): ')
adj2 = input('Enter an adjective: ')
adj3 = input('Enter an adjective: ')
adj4 = input('Enter an adjective: ')

print('The ', color1, ' Dragon is the ', superlative, ' Dragon of all. It has ', adj1, ' ', body_part_plural, ' , and a ', body_part, ' shaped like a ', noun1, '. It loves to eat ', animal1, ' , although it wil feast on nearly anything. It is ', adj2, ' and ', adj3, '. You must be ', adj4, ' around it, or you may end up as its meal!')
# Out:
# Enter a color: red
# Enter a superlative (ending in "est"): greatest
# Enter an adjective: strong
# Enter a body part (plural): arms
# Enter a body part: leg
# Enter a noun: basketball
# Enter an animal (plural): cows
# Enter an adjective: fast
# Enter an adjective: beautiful
# Enter an adjective: mute
# The  red  Dragon is the  greatest  Dragon of all. It has  strong   arms  , and a  leg  shaped like a  basketball . It loves to eat  cows  , although it wil feast on nearly anything. It is  fast  and  beautiful . You must be  mute  around it, or you may end up as its meal!

# %% [markdown]
# Extra Credit Selfie: https://drive.google.com/file/d/155086rdgdSNXxtibjhSE7-bNpX3NJS5j/view?usp=sharing

# %%
#function to find radius of a sphere
def sphere_volume():
    volume = (4/3) * math.pi * radius**3
    return volume

# %% [markdown]
# Open In Colab
# Problem Set 1
#
# CMSI 1010: Computer Programming and Lab
# Important Dates
#
# Released: 2024-01-23 at 12:00 am [PT]
# Deadline: 2024-01-30 at 11:59 pm [PT]
# Question 1: Reading
#
# Chapter 2 in the Think Python textbook: http://greenteapress.com/thinkpython2/thinkpython2.pdf
# In your own words, summarize the key topics covered in the textbook chapter. Additionally, relate these topics to the concepts and material we've learned in class. How do the ideas presented in the chapter connect to the lessons and discussions we've had in the classroom? Please provide specific examples to support your points.
#
# --Your reading summary notes go here--
#
# 2.1 Assignment Statements
# - Variables are names for values
# - Assignment creates a variable, assigns a value
#
# 2.2 Variable Names
# - Meaningful, any length, alphanumeric
# - Can't start with a number
# - Conventional: lowercase with underscores
#
# 2.3 Expressions and Statements
# - Expression: Combo of values, variables, operators
#
# 2.4 Script Mode
# - Python: Interactive or script mode
# - Scripts: .py extension
# - Script expressions need print statements
#
# 2.5 Order of Operations
# - Follows PEMDAS
# - Use parentheses to control order
#
# 2.6 String Operations
# - Limited mathematical operations on strings
# - Exception: + for concatenation, * for repetition
#
# 2.8 Debugging
# - Three errors: Syntax, Runtime, Semantic
# - Syntax: Structure-related, immediate termination
# - Runtime: During execution, exceptions
# - Semantic: Related to meaning, causes unexpected behavio
#
# Question 2
#
# Refer to the above link for the following exercises and edit this file with your answers. Try to take full advantage of Markdown so that your answers are clearly and beautifully formatted!
#
# Part A
#
# Textbook exercise 2.1
#
# We’ve seen that n = 42 is legal. What about 42 = n?
#
# Answer: 42 = n is not legal because the variable name needs to be on the left side of the '='
#
# -- your response here -- double click to type
#
# How about x = y = 1?
#
# Answer = this is legal in python and is actually assigning the value of '1' to two different variables at the same time
#
# -- your response here --
#
# In some languages every statement ends with a semi-colon ;. What happens if you put a semi-colon at the end of a Python statement?
#
# Answer: semicolons in python are allowed but only to seperate statements if written on the same line, but they are nor necessary
#
# -- your response here --
#
# What if you put a period at the end of a statement?
#
# Answer: this would result in a syntax error as python does not rely on periods to determine if a statement is finished or not
#
# -- your response here --
#
# In math notation you can multiply x and y like this: x y. What happens if you try that in Python?
#
# Answer: If you tried this in python, you would receive a syntax error as the correct way to multiply two values is by using the '*' symbol
# -- your response here --
#
# Part B
#
# Textbook exercise 2.2 (parts 1, 2, and 3)
#
# Practice using Python as a calculator:
#
# The volume of a sphere with radius
# r
#  is
# 4
# /
# 3
# π
# r
# 3
# . Write a function to get the volume of the sphere given its radius.
#
# In [ ]:
# from math import pi
#
# def sphere_volume(radius):
#     """Return the volume of a sphere with radius `radius`."""
#     # your code here
#     return 0.0
#
#
# # Run this cell to test your function!
# assert round(sphere_volume(2), 1) == 33.5
# assert round(sphere_volume(4), 1) == 268.1
# assert round(sphere_volume(5.5), 1) == 696.9
# Suppose the cover price of a book is
# $
# 24.95
# , but bookstores get a
# 40
# %
#  discount. Shipping costs
# $
# 3
#  for the first copy and 75 cents for each additional copy. Write a function to calculate the total wholesale cost given the number of copies.
#
# In [ ]:
# def total_wholesale_cost(copies):
#     """Return the total wholesale cost of `copies` copies."""
#     # your code here
#     return 0.0
#
# # Run this cell to test your function!
# assert (round(total_wholesale_cost(60), 2) == 945.45)
# assert (round(total_wholesale_cost(100), 2) == 1574.25)
# assert (round(total_wholesale_cost(200), 2) == 3146.25)
# A runner runs easy_miles at an easy pace (8:15 per mile) and tempo_miles miles at tempo pace (7:12 per mile). Write a function to calculate the total time of the run in seconds.
#
# In [ ]:
# def run_total_seconds(easy_miles, tempo_miles):
#     """Return the total seconds of a run with `easy_miles` miles at an easy pace
#     and `tempo_miles` miles at a tempo pace."""
#     # your code here
#     return 0
#
# # Run this cell to test your function!
# assert (run_total_seconds(3, 2) == 2349)
# assert (run_total_seconds(5, 3) == 3771)
# assert (run_total_seconds(10, 5) == 7110)
# Question 3
#
# Programming: Write a Mad Lib
#
# Mad Libs are word games where one player fills in the blanks of another player’s story by providing words of certain types. When the words are substituted in for the blanks, the result is a complete, grammatically correct, but often nonsensical, story.
#
# In this question, we are going to write a program that lets the user make a Mad Lib!
#
# First, you will need a Mad Lib: feel free to write your own or choose one from http://www.madglibs.com
#
# Now, using the input function we learned in class, prompt the user for words to fill in the blanks. Ask the user for at least four (4) values (e.g., ADJ, NOUN, VERB, etc.).
#
# In [ ]:
# # your code here
# Finally, print out the story for the user!
#
# In [ ]:
# # your code here
# Optional: Submit a selfie with a CMSI TA!
# Do this: Upload the selfie image to this notebook by uploading the image to your google drive and make sure it's a public folder and get the shareable link by right-clicking on the picture and choose 'Get a sharable link'. You just need the id of the image so copy that (the id is between /d/ and /view). There is a text cell below but it is invisible, you have to click below to make it show. Now paste the ID in the link below where it says "PASTE ID HERE."
